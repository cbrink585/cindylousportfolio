# %%
from selenium import webdriver
from BeautifulSoup import BeautifulSoup
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/8v/s97w1sj53zvbn_x15rw782mm0000gp/T/ipykernel_4396/587376086.py in <module>
#       1 from selenium import webdriver
# ----> 2 from BeautifulSoup import BeautifulSoup
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'BeautifulSoup'

# %%
! pip install BeautifulSoup

# %%
! pip install selenium

# %%
from selenium import webdriver
from BeautifulSoup4 import BeautifulSoup4
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/8v/s97w1sj53zvbn_x15rw782mm0000gp/T/ipykernel_4396/416660223.py in <module>
#       1 from selenium import webdriver
# ----> 2 from BeautifulSoup4 import BeautifulSoup4
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'BeautifulSoup4'

# %%
! pip install BeautifulSoup4
pip install BeautifulSoup4
# Out:
#   File "/var/folders/8v/s97w1sj53zvbn_x15rw782mm0000gp/T/ipykernel_4396/2781453128.py", line 2
#     pip install BeautifulSoup4
#         ^
# SyntaxError: invalid syntax

# %%
conda install -c anaconda beautifulsoup4
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import beautifulsoup4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/8v/s97w1sj53zvbn_x15rw782mm0000gp/T/ipykernel_4396/1546174520.py in <module>
# ----> 1 import beautifulsoup4
#
# ModuleNotFoundError: No module named 'beautifulsoup4'

# %%
import pandas as pd

# %%
#import csv file skip first two rows
df = pd.read_csv('Accidents_and_fatalities_per_year.csv', skiprows=1)

# %%
df
# Out:
#      Year  Accidents   Fatalities  Unnamed: 3  Accidents .1  Fatalities.1  \
# 0    1946          73         842         NaN            73           842
# 1    1947          82        1083         NaN            84          1093
# 2    1948          99        1303         NaN           100          1328
# 3    1949          81        1109         NaN            84          1155
# 4    1950          71        1124         NaN            71          1124
# ..    ...         ...         ...         ...           ...           ...
# 73   2019          23         287         NaN            23           287
# 74   2020           8         136         NaN            10           318
# 75   2021          20         173         NaN            20           173
# 76   2022          22         243         NaN            22           243
# 77  TOTAL        3932       80635         NaN          4096         87377
#
#     Unnamed: 6  Accidents .2  Fatalities.2  Unnamed: 9  ...  Unnamed: 13  \
# ...

# %%
column_names = ['Year', 'Accidents .1', 'Fatalities.1', 'Accidents .2', 'Fatalities.2']
df.to_csv("/Users/CLB/Documents/DSC640/DSC640/df_accidents_by_year.csv", index=False, columns=column_names)
df
df.dtypes
df['Year'] = df['Year'].astype('int')

# %%
df_revenue= pd.read_excel('passenger_revenue_editted.xlsx', sheet_name=None)
#result = df_revenue.dtypes

# %%
df_data = df_revenue.get('Data')
df_data
# Out:
#     Year  Revenue
# 0   1946     0.00
# 1   1947     0.00
# 2   1948     0.00
# 3   1949     0.00
# 4   1950     0.00
# ..   ...      ...
# 67  2017   130.49
# 68  2018   138.98
# 69  2019   145.44
# 70  2020    49.89
# 71  2021    86.67
#
# [72 rows x 2 columns]

# %%
df_data.dtypes
# Out:
# Year         int64
# Revenue    float64
# dtype: object

# %%
new_df = pd.concat([df_data, df], axis=0)#Nope start here by figuring how to make both year columns the same data type don't use new_df it's a mess!
new_df
# Out:
#     Year  Revenue  Accidents   Fatalities  Unnamed: 3  Accidents .1  \
# 0   1946      0.0         NaN         NaN         NaN           NaN
# 1   1947      0.0         NaN         NaN         NaN           NaN
# 2   1948      0.0         NaN         NaN         NaN           NaN
# 3   1949      0.0         NaN         NaN         NaN           NaN
# 4   1950      0.0         NaN         NaN         NaN           NaN
# ..   ...      ...         ...         ...         ...           ...
# 72  2018      NaN        18.0       561.0         NaN          19.0
# 73  2019      NaN        23.0       287.0         NaN          23.0
# 74  2020      NaN         8.0       136.0         NaN          10.0
# 75  2021      NaN        20.0       173.0         NaN          20.0
# 76  2022      NaN        22.0       243.0         NaN          22.0
#
#     Fatalities.1  Unnamed: 6  Accidents .2  Fatalities.2  ...  Unnamed: 13  \
# ...

# %%
new_df.to_excel('/Users/CLB/Documents/DSC640/DSC640/new_df.xlsx')

# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import csv file skip first two rows
df2= pd.read_csv('airline-safety.csv')

# %%
df2
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
#import csv file skip first two rows
df2= pd.read_excel('airline_revenue2.xlsx')

# %%
df2
# Out:
#                                  Unnamed: 0 1960 1965 1970 1975 1980 1985  \
# 0  Air carrier, domestic, scheduled service    N    N    N    N    N    N
# 1                        Index (1993 = 100)  NaN  NaN  NaN  NaN  NaN  NaN
#
#   1990 1991 1992  ...        2012        2013        2014        2015  \
# 0    N    N    N  ...   18.914111   19.276935   19.895380   19.208835
# 1  NaN  NaN  NaN  ...  107.028868  109.081974  112.581555  108.696619
#
#          2016        2017        2018        2019       2020       2021
# 0   18.341284   18.338816   18.530278   18.616702  15.254559  15.599734
# 1  103.787426  103.773460  104.856884  105.345928  86.320641  88.273876
#
# [2 rows x 39 columns]

# %%
#df2_transposed = df2.T
#df2_transposed
#df2_transposed
#df_cleaned = df2_transposed.iloc[1:, :]

#df_cleaned  I have a better data set for revenue- don't use this one!
# Out:
#               0           1
# 1960          N         NaN
# 1965          N         NaN
# 1970          N         NaN
# 1975          N         NaN
# 1980          N         NaN
# 1985          N         NaN
# 1990          N         NaN
# 1991          N         NaN
# 1992          N         NaN
# 1993  17.671971       100.0
# 1994  16.592215   93.890005
# 1995  16.871032   95.467744
# 1996  15.931889   90.153434
# 1997  16.517022   93.464513
# 1998  17.041248   96.430938
# 1999   17.17382   97.181124
# 2000  17.752569  100.456078
# 2001  16.174248   91.524868
# 2002  15.336473   86.784165
# 2003  15.218101    86.11434
# 2004  14.581286   82.510806
# 2005  14.934047   84.506968
# 2006  16.244878   91.924541
# 2007  16.246834   91.935604
# 2008  17.454744   98.770781
# 2009  16.002731   90.554307
# 2010  17.160317   97.104711
# 2011  18.356445  103.873214
# 2012  18.914111  107.028868
# 2013  19.276935  109.081974
# 2014   19.89538  112.581555
# 2015  19.208835  108.696619
# ...

# %%
df_cleaned
# Out:
# ['Year', 'ColA', 'ColB']

# %%
df_revenue= pd.read_excel('passenger_revenue_editted'.xlsx)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/8v/s97w1sj53zvbn_x15rw782mm0000gp/T/ipykernel_2979/1678796793.py in <module>
# ----> 1 df_revenue= pd.read_excel('passenger_revenue_editted'.xlsx)
#
# AttributeError: 'str' object has no attribute 'xlsx'

# %%
df_revenue= pd.read_excel('passenger_revenue_editted.xlsx', sheet_name=None)

# %%
df_revenue
# Out:
# {'Overview':     Unnamed: 0                                         Unnamed: 1  \
#  0          NaN                                                NaN
#  1          NaN                       Statistic as Excel data file
#  2          NaN  Passenger fare revenue generated within the U....
#  3          NaN                                        Access data
#  4          NaN                                                NaN
#  5          NaN                                                NaN
#  6          NaN                                             Source
#  7          NaN                                                NaN
#  8          NaN                                             Source
#  9          NaN                                       Conducted by
#  10         NaN                                      Survey period
#  11         NaN                                             Region
#  12         NaN                                     Type of survey
# ...

# %%
df_data = df_revenue.get('Data')

# %%
df_data
# Out:
#     Year  Revenue
# 0   2009    91.44
# 1   2010   103.98
# 2   2011   114.30
# 3   2012   115.97
# 4   2013   121.36
# 5   2014   127.46
# 6   2015   127.06
# 7   2016   125.92
# 8   2017   130.49
# 9   2018   138.98
# 10  2019   145.44
# 11  2020    49.89
# 12  2021    86.67
